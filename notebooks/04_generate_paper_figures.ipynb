# %% [markdown]
# # Generate paper figures
#
# Template for generating reproducible figures from CSV outputs.

# %%
from rail_ifc_quality_gate.cli import main
print('See README for CLI usage. This notebook is a lightweight template.')
